# %%
import pandas as pd
import re

# %%
rows = []
with open('mappingbased_literals_en.ttl', 'r', encoding="utf8") as f:
    f.readline()
    for l in f.readlines():
        #print(l)
        try:
            split = l.split('"')
            split2 = split[0].split(' ')
            rows.append((split2[0], split2[1], split[1]))
        except:
            print(l)
            
df = pd.DataFrame.from_records(rows, columns=['from', 'relation', 'to'])
# Out:
# # completed 2017-04-01T01:13:52Z

# %%
stats = []

for key,group in df.groupby('relation'):
    total = 0
    letters = 0
    subset = group.sample(n=100 if len(group) > 100 else len(group))['to']
    for w in subset:
        total += len(w)
        letters += len(re.findall(r'[a-zA-Z]', w))
    stats.append((key, total/len(subset), letters/total, len(group)))
    
stats_df = pd.DataFrame.from_records(stats, columns=['relation', 'average_length', 'letter_percent', 'n'])
# Out:
# c:\Users\Jeremy\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
relations = stats_df[(stats_df['n'] >= 10) & (stats_df['letter_percent'] > .6) & (stats_df['average_length'] >= 4)]['relation']


df_subset = df[df['relation'].isin(relations)]
df_subset['from'] = df_subset['from'].str.strip(r'[<>]').str.split('__', expand=True)[0].str.split('/', expand=True)[4].str.replace('_', ' ')
# Out:
# c:\Users\Jeremy\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_subset.to_csv('dbpedia_literals_cleaning.csv', index=False)

# %%
for key, group in df_subset.groupby('relation'):
    print(key)
    print(list(group.head(10)['to']))
# Out:
# <http://dbpedia.org/ontology/aSide>
# ['Rage Hard', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\']
# <http://dbpedia.org/ontology/abbreviation>
# ['ANSI', 'Algorithms', 'Aqr', 'Ari', 'Ant', 'Aps', 'Ara', 'Ann. Math.', 'SIG', 'Boo']
# <http://dbpedia.org/ontology/access>
# ['Offshore anchorage only; steep cliffs make boat landing impossible', 'ViaA1066 roadbetweenDissandThetford', 'Controlled', 'State Route 447', 'Rua da Ponte Romana; Rua Cândido Sotto Mayor', 'Rua Conde Dom Henrique', 'E.N.365/118,from Vila Nova da Barquinha', 'car', 'State Route 447', 'Rua do Castelo']
# <http://dbpedia.org/ontology/address>
# ['92,Passeig de Gràcia(passeig is Catalan for promenade)', "183Queen's Road East", '4303 S. Providence Road', '82, Rue de Villiers', '78300 Poissy', '1600Pennsylvania Avenue', 'NW Washington, D.C. 20500U.S.', 'Plac Defilad1', '82 Boulevard de Clichy', '1 Ying Wa Street']
# <http://dbpedia.org/ontology/agencyStationCode>
# ['WAT', 'KGX', 'BRI', 'BPW', 'LST', 'PAD', 'WLT', 'EUS', 'MYB', 'Amtrak:NYP']
# <http://dbpedia.org/ontology/alias>
# ['Hitch', 'The Master of Suspense', 'Björn & Benny, Agnetha & Anni-Frid', '\\', 'ACSS, Afrocelts', 'Amaury De Bène (French), Amalricus (Latin)', 'Américo Vespucio[[[Spanish (language)|es]]]', 'Americus Vespucius[[[Latin language|la]]]', 'Américo Vespúcio[[[Portuguese language|pt]]]', 'Alberigo Vespucci']
# <http://dbpedia.org/ontology/allegiance>
# ['United States of America', 'Republic of Texas', 'Confederate States of America', 'United States of America', 'Union', 'United Kingdom', '*Union', 'United States', '23pxBritish Empire', 'United Kingdom']
# <http://dbpedia.org/ontology/alternativeName>
# ['Birkenau', 'Polizeiliches Durchgangslager Westerbork', 'SS-Sonderkommando Sobibor', 'KL Lublin', 'Mauthausen, Gusen', 'S-21', 'Mittelbau-Dora', 'Colonia Dignidad', 'Kulmhof', 'SS-Auffanglager Breendonk']
# <http://dbpedia.org/ontology/atcSupplemental>
# ['(combination withestrogen)', ',', '(in combinations)', ',', ',(combinations),,,', ',,,,,,,', '((L) form)', '(oxide)', ',', ',,,,,']
# <http://dbpedia.org/ontology/background>
# ['group_or_band', 'group_or_band', 'group_or_band', 'group_or_band', 'group_or_band', 'group_or_band', 'solo_singer', 'solo_singer', 'solo_singer', 'group_or_band']
# <http://dbpedia.org/ontology/battingSide>
# ['Left', 'Right', 'Right', 'Right', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right']
# <http://dbpedia.org/ontology/battleHonours>
# ['seeBattle honours', 'Livonian Crusade', 'World War I', '*St. Mihiel', '*Meuse-Argonne', '*Lorraine 1918', 'World War II', '*Normandy (with arrowhead)', '*Northern France', '*Rhineland']
# <http://dbpedia.org/ontology/bestFinish>
# ['Quarter-finals,', 'World Snooker Championship', '(4 times)', 'Quarter-final (2013 Welsh Open,2013 Indian Open)', 'Runner-up (1997 International Open)', 'Semi-final:Irish Masters(2004)', 'Runner-up (1974 World Championship)', 'Final (1978 World Championship)', 'Semi-final (1977 World Championship)', 'Final (1975 World Championship)']
# <http://dbpedia.org/ontology/bicycleInformation>
# ['No', '180', '115 spacebicycle station', 'two racks', 'One locker, one rack', 'two racks', 'Two lockers, one rack', 'One locker, one rack, one lid', 'two lockers, one rack', 'two lockers, one rack']
# <http://dbpedia.org/ontology/birthName>
# ['Joseph Aloysius Dwan', "Alisa Zinov'yevna Rosenbaum", 'Aldous Leonard Huxley', 'Andrei Arsenyevich Tarkovsky', 'Alfred Joseph Hitchcock', 'Alfred Bernhard Nobel', 'Andrew Warhola', 'Alfred Elton van Vogt', 'Alan Alexander Milne', 'August William Derleth']
# <http://dbpedia.org/ontology/brainInfoType>
# ['hier', 'hier', 'ancil', 'hier', 'hier', 'hier', 'hier', 'hier', 'hier', 'ancil']
# <http://dbpedia.org/ontology/bridgeCarries>
# ['6 lanes of, bike/pedestrian', '6 lanes of ([[#Traffic', '4 lanes of', '*', 'Bradfield Highway', 'North Shore railway line', '* 1', 'pedestrian way', 'cycleway', '10 lanes of']
# <http://dbpedia.org/ontology/callSign>
# ['ABC', 'K6BP', 'Alpha, Station', 'ex-WA6BND (ex-WV6VLY)', 'Skylab', 'K9OX', 'WABC-TV', 'N6NHG', 'Mir', 'WAPA-TV']
# <http://dbpedia.org/ontology/callsignMeaning>
# ['Australian', 'Broadcasting', 'Corporation', '3 - Victoria', 'CAT -Geelong Cats', 'American Broadcasting Company', 'Asociación de Productores de Azúcar', "World's Largest Store (original ownerSears)", 'Nippon Hōsō Kyōkai', 'Special']
# <http://dbpedia.org/ontology/campusType>
# ['Urban', 'Rural', 'suburban', 'Urban', 'Suburban', 'Suburban,College Town', 'Large city', 'suburban', 'Rural', 'Suburban']
# <http://dbpedia.org/ontology/canBaggageChecked>
# ['false', 'true', 'true', 'true', 'true', 'true', 'true', 'false', 'true', 'false']
# <http://dbpedia.org/ontology/causalties>
# ['United States:', '6,824 killed in battle', '25,000–70,000 dead from all causes', 'Overall casualties up to 50,000', 'France: 10,000 battle deaths (75% at sea)', 'Spain: 5,000 killed', 'Netherlands: 500 killed', '110,000+ killed in action/died of wounds', '230,000+ accident/disease deaths', '25,000–30,000 died in Confederate prisons']
# <http://dbpedia.org/ontology/certification>
# ['Gold(RIAA)', 'Gold(RIAA)', 'Gold (RIAA)', 'Platinum', 'Gold (RIAA)', 'Gold (Music Canada)', 'Silver (BPI)', '2&times; Platinum (RIAA)', '2x Platinum (RIAA)', 'Gold (RIAA)']
# <http://dbpedia.org/ontology/chairmanTitle>
# ['President', 'President', 'President', 'President', 'President', 'Owner', 'Co-chairmen', 'President', 'President', 'Managing Director']
# <http://dbpedia.org/ontology/characterInPlay>
# ['Nora', 'Torvald Helmer', 'Krogstad', 'Mrs. Linde', 'Dr. Rank', 'Children', 'Anne-Marie', 'Helene', 'Rosencrantz', 'Guildenstern']
# <http://dbpedia.org/ontology/chorusCharacterInPlay>
# ['ThebanElders', 'Bacchae, female followers of Dionysus', 'ThebanWomen', 'Theban Elders', 'Elders ofArgos', 'Slave women', 'TheErinyes', 'Clouds (goddesses)', 'Athenian Women', 'knights']
# <http://dbpedia.org/ontology/cityType>
# ['town', 'town', 'community', 'community', 'town', 'town', 'town', 'town', 'community', 'town']
# <http://dbpedia.org/ontology/coachingRecord>
# ['Most wins in college football history (489)', ';Player', '*Dukecareer consecutive games started (138, 1986–)', '*ACCsingle-season games started (40, 1986–)', '*ACC single-season games played (40, 1986–)', ';Coach', "*Harvard's firstNCAA Tournamentvictory (2013)", '*Harvardwin v. highest ranked opponent', '*:AP Poll(#17, 2009–2013; #10, 2013–present)', "*:Coaches' Poll(#24, 2009–2011; #20, 2011–2013; #10, 2013–present)"]
# <http://dbpedia.org/ontology/code>
# ['.pt', '.pt', 'Francis-type', '920–925', '367228042515100', '361013025007460', '367224040815120', '38-36-13', '367210085505020', '367230034202060']
# <http://dbpedia.org/ontology/coden>
# ['ANMAAH', 'CNSTES', 'CCEYAS', 'SJUED4', 'NATUAS', 'BASIAP', 'FRNAA3', 'SCIEAS', 'ANJOAA', 'PNASA6']
# <http://dbpedia.org/ontology/collection>
# ['approx. 8 million objects', '1 million objects', '696,373 (as of December 2015)', '10,700,000 items or collections of items.', '120,000 items', '170,000 – 200,000', '500,000 items', 'sailing ships andboats', '1,854', 'Animals']
# <http://dbpedia.org/ontology/colourName>
# ['greenyellow', 'rgb(200,250,80)', 'greenyellow', 'Black, green, gold', 'violet', 'lightgrey', 'Red, white and blue', 'Yellow', '\\', '\\']
# <http://dbpedia.org/ontology/combatant>
# ['Thirteen Colonies(before 1776)', 'United States(after 1776)', 'Vermont(from 1777)', 'France(from 1778)', '----', 'Spain(from 1779)', 'Native Americans', 'Mysore', '*German auxiliaries', '*Loyalists']
# <http://dbpedia.org/ontology/committee>
# ['Senate Committee on Government Operations', 'Legislative Council of Mumbai', 'United States railroad commissioner 1893–1897', 'N/A', 'Justice Committee(Member08 Jun 2016 - In Office(Scottish Parliament)', 'Rural Economy and Connectivity Committee(Member08 Jun 2016 - In Office(Scottish Parliament)', 'Standing Orders & Agenda Committee', 'Member', '(SNP)', 'Standing Committee on Public Accounts - Chairman (1997-1999) & Vice-Chairman (1994-1996)']
# <http://dbpedia.org/ontology/configuration>
# ['straight-four', 'straight-four', 'straight-four', 'straight-four', 'V8', 'straight-four', 'straight-four', 'straight-four', 'straight-four', 'F4']
# <http://dbpedia.org/ontology/crownDependency>
# ['Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man', 'Isle of Man']
# <http://dbpedia.org/ontology/cuisine>
# ['Scotland', 'Japanese cuisine', 'Asian-inspiredNew American', 'Indonesian', 'Various East European cuisines', 'Malaysian', 'Thai', 'United States', 'French', 'Coffee&beignets']
# <http://dbpedia.org/ontology/currentStatus>
# ['active', 'Active', 'Active', 'Active', 'Defunct ()', 'Defunct (as a social networking site)', 'Closed (as a social gaming site)', 'Invitation Only (relaunch)', 'active', 'Active']
# <http://dbpedia.org/ontology/currentlyUsedFor>
# ['Opera and Ballet', 'Music venue', 'Lumière Place', 'Times Square Church', 'Performing arts center', 'live event venue', 'live music venue', 'Cinema', 'cinema and live event venue', 'live event venue']
# <http://dbpedia.org/ontology/demonym>
# ['Alabaman or Alabamian', 'Algerian', 'Andorran', 'Alaskan', 'Asian', 'Aruban', 'Angolan', 'Afghanref|Other terms that have been used as demonyms are Afghani and Afghanistani.|name=\\', 'Albanian', 'Azerbaijani']
# <http://dbpedia.org/ontology/depictionDescription>
# ['The main entrance to Auschwitz II (Birkenau)', 'Carl Menger, founder of the Austrian School', 'Portrait of David Ricardo byThomas Phillips, circa 1821. This painting shows Ricardo, aged 49, just two years before his death.', 'Eli Whitney, painted bySamuel F. B. Morse, 1822.Yale University Art Gallery', 'Émile Baudot', 'Wankel in the 1960s', 'Tobin in 1962', 'Friedman in 2004', 'Cover of the infamous \\', 'Cover of the first Punch, or The London Charivari, depicts Punch hanging a caricaturedDevil, 1841 (seegallery belowfor enlarged detail)']
# <http://dbpedia.org/ontology/description>
# ['Performed by theUnited States Navy Bandand Sea Chanters, arr. Carmen Dragon', 'United States Army BandBrass version', 'A sample of effects that can be achieved with the bellows—949 KB', 'A 1916 recording of \\', 'Chords being played on an accordion – 145 KB', 'Audio clip of the same octave cycled through five different timbres (Piano Accordion) – 676 KB', "George H. W. Bush's July 26, 1990 Remarks on the Signing of the Americans with Disabilities Act", "This version also includes Newton's sixth verse, which is uncommon in recordings. This recording was made for the American Folklife Center  and is in theU.S. Library of Congress", 'This recording was done for the Archive of American Folk-Song in Livingston, Alabama in 1939, and is in the U.S. Library of Congress', 'Collins transitions from her solo voice to the chorus backing her up']
# <http://dbpedia.org/ontology/detectionMethod>
# ['Light curve', 'Light-curve', 'Light curve', 'Doppler Spectroscopy', 'radial velocity', 'Light curve', 'Light-curve', 'Light curve', 'radial velocity', 'Radial velocity']
# <http://dbpedia.org/ontology/digitalSubChannel>
# ['4.1Independent', '4.2WAPA 2 Deportes', '11.1 PBS', '11.2 WTTW Prime', '11.3', 'Create', '/', 'World', '11.4', 'V-me']
# <http://dbpedia.org/ontology/draft>
# ['7th overall', '13th overall', '1st overall', '4th overall', '134th overall', 'Allocated', '4th overall', 'Undrafted', '5th overall', '2nd overall']
# <http://dbpedia.org/ontology/dressCode>
# ['Casual', 'Casual', 'Formal', 'Casual', 'Casual', 'Casual', 'Jacket required', 'Casual', 'Casual', 'Casual']
# <http://dbpedia.org/ontology/editorTitle>
# ['Editor', 'Editor', 'Editor-in-chief', 'Managing editor', 'Managing Editor', 'Editor', 'Editor', 'Editor-in-Chief', 'Editor In Chief', 'Editor-in-Chief']
# <http://dbpedia.org/ontology/eyeColor>
# ['Brown', 'Blue', 'Blue', 'Green', 'Blue', 'Brown', 'Light Brown', 'Blue', 'Blue', 'Dark brown']
# <http://dbpedia.org/ontology/faaLocationIdentifier>
# ['LAX', 'IAD', 'BWI', 'DMA', 'VNY', 'SJU', 'JFK', 'PTY', 'VPS', 'EIL']
# <http://dbpedia.org/ontology/fansgroup>
# ['La Revo 1928', 'Macro Azurra', 'Mega Locos', 'Patrons of Varsity Reds Soccer', 'Gençlik27', 'Yalı', 'Shooters Soccer Fan Club', 'Onbeşliler', 'Baraberi', 'Gefe Fans, Ultras 77']
# <http://dbpedia.org/ontology/fareZone>
# ['1', '1', '1', '2', '1', '2', '1', '2', '5', '1 (Public transport fares in the Île-de-France)']
# <http://dbpedia.org/ontology/fate>
# ['Privatised', 'Sold toHispano-Suiza(1963)', 'Sold toVolkswagen Group(July 1998)', 'Merger', 'Acquired 1973 byManganese Bronze Holdings', 'effectively bankrupt', 'Acquired by Rolls-Royce Limited (1931)', 'Acquired by Vickers plc (1980)', 'Acquired by', 'Volkswagen Group']
# <http://dbpedia.org/ontology/filename>
# ['America the Beautiful (US Navy Band).ogg', 'America (US Army Brass).ogg', 'Frase de Neil Armstrong.ogg', 'AccordionBellowsSounds.ogg', 'Pietro Frosini - New York Blues (1916) - hiss reduced.ogg', 'Accordion chords-01.ogg', 'Accordion_registers.ogg', 'George HW Bush Americans with Disabilities Act.ogg', 'Amazing Grace_-_Sacred Harp Singing Society.ogg', 'Amazing grace2.ogg']
# <http://dbpedia.org/ontology/firstAppearance>
# ['\\', 'The Mysterious Affair at Styles', "Alice's Adventures in Wonderland", 'Alice in Wonderland', 'November 18, 1985', '* November 18, 1985 (Dad)', '* November 26, 1985 (Mom)', 'December 5, 1985', 'Weird Tales (December 1932)', 'The Knight of the Swords (1971)']
# <http://dbpedia.org/ontology/firstGame>
# ['Hearts1–0 Hibernian', '(Edinburgh, Scotland; 25 December 1875)', 'DCU2–0 MIA', 'March 15, 1998Lockhart Stadium', 'Washington Freedom 1–0Bay Area CyberRays(RFK Stadium; April 14, 2001)', 'inThessalonikivsIraklis FC. Result: Win by 2–1.', 'C.D. Atlético Balboa2 – 2 San Salvador', '(Estadio Cuscatlán; January 20, 2002)', 'Last Game', 'Juventud Independiente3 – 1 San Salvador']
# <http://dbpedia.org/ontology/flag>
# ['Flag of Algeria.svg', 'Flag of Andorra.svg', 'Flag of Aruba.svg', 'Flag of Angola.svg', 'Flag of Afghanistan.svg', 'Flag of Albania.svg', 'Flag of Azerbaijan.svg', 'Flag of Antigua and Barbuda.svg', 'Flag of Anguilla.svg', 'Flag of Belgium.svg']
# <http://dbpedia.org/ontology/formerName>
# ["Queen's College (1838–1841)", 'Acadia College (1841–1891)', 'Australian Broadcasting Company(1929–1932)', 'Australian Broadcasting Commission (1932–1983)', 'BBC Text (1999-2001)', 'BBCi (2001-2008)', 'BBC News 24 (1997–2008)', "King's College", '(1754-1784)', 'Columbia College']
# <http://dbpedia.org/ontology/frequencyOfPublication>
# ['Quarterly', 'Bimonthly', 'Quarterly', 'Monthly', 'Biennial', 'Biannual', 'Weekly', 'Bimonthly', 'Quarterly', 'Monthly']
# <http://dbpedia.org/ontology/frozen>
# ['Practically all year round', 'January–May', 'mid-December to mid-June', '1929, 1962/1963 (last)', '1795, 1830, 1880 (partial), 1963', 'Never', 'never', 'never', 'in the 17th and 19th century; Lucerne Bay and Lake Alpnach in 1929 and 1963', 'November - mid June']
# <http://dbpedia.org/ontology/fuelType>
# ['diesel', 'diesel', 'diesel', 'diesel', 'diesel', 'diesel', 'diesel', 'petrol', 'petrol', 'petrol']
# <http://dbpedia.org/ontology/generationUnits>
# ['1 x', '12×Francis-type', '6 x', '2 x 100MWFrancis-type', '5 × 275MW,3 × 310MW, 2 × 306MW', '2', '2', '2', '1', '3']
# <http://dbpedia.org/ontology/geologicPeriod>
# ['Miocene', 'Holocene', 'Holocene', 'Pleistocene', 'Holocene', 'Holocene', 'Holocene', 'Holocene,Pliocene', 'Holocene', 'Silurian']
# <http://dbpedia.org/ontology/geology>
# ['Alkali basalt', 'Tephra', 'Trachyte', 'Trachybasalt', 'arkose', 'Basin and Range Province', 'Basin and Range Province', 'Devonian', 'Carboniferous', 'Limestone']
# <http://dbpedia.org/ontology/hairColor>
# ['Brown', 'Blonde', 'Auburn', 'Light Brown', 'Dark Brown', 'Brown', 'Blonde', 'Blonde', 'Red', 'Dark brown']
# <http://dbpedia.org/ontology/headLabel>
# ['Headmaster', 'Headmaster', 'Head Master', 'Headmaster', 'Head Master', 'Rector', 'Headmaster', 'Master of the College', 'Chairman', 'Head Master']
# <http://dbpedia.org/ontology/icaoLocationIdentifier>
# ['KXTA', 'EGLL', 'KLAX', 'EHAM', 'EETN', 'KIAD', 'EGBK', 'KBWI', 'LGAV', 'ETAR']
# <http://dbpedia.org/ontology/identificationSymbol>
# ['100px', 'centre|border|100px', '200px', '100px|center', '200px|center', 'FFL (English)', 'LE (French)', '200px', 'border|100px', '100px']
# <http://dbpedia.org/ontology/ingredientName>
# ['Tapioca, milk/creamer, brewed tea, sugar, water', 'Potatoes,Cabbage,Brussels sprouts,vegetables', 'Spices,herbs, usually fresh or dried hotpeppers/chillies', 'Semolina', 'Romaine lettuce,croutons,Parmesancheese,lemonjuice,olive oil,egg,Worcestershire sauce,black pepper', 'Chocolate liquor,cocoa butterfor white chocolate, often with addedsugar', '*', 'Potato', 'es', 'Oil']
# <http://dbpedia.org/ontology/interest>
# ['Biological', 'Biological', 'Biological', 'Biological, historical', 'Biological/Geological', 'Biological', 'biological, historical, ornithological', 'Biological/Geological', 'Biological', 'Biological']
# <http://dbpedia.org/ontology/internationally>
# ['true', 'true', 'true', 'true', 'true', 'true', 'true', 'true', 'true', 'true']
# <http://dbpedia.org/ontology/isHandicappedAccessible>
# ['true', 'true', 'true', 'true', 'true', 'true', 'true', 'true', 'true', 'true']
# <http://dbpedia.org/ontology/isPartOfName>
# ['B100', '(NJ side)', '(NY side)', 'Kingsway Tunnel', 'Queens Way', 'x13pxRN205', 'x20pxTraforo T1', 'European route E25', '(NJ side)', '(full span)']
# <http://dbpedia.org/ontology/isoCodeRegion>
# ['CH-AG', 'PK-JK', 'PK-BA', 'CH-BS', 'GR-M', 'MX-CHP', 'ES-CT', 'SE', 'BE-VLG', 'NL-FY']
# <http://dbpedia.org/ontology/iupacName>
# ['Azane', '(2S,5R,6R)-6-([(2R)-2-amino-2-phenylacetyl]amino)', '-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-', 'carboxylic acid', '(5R)-[(1S)-1,2-Dihydroxyethyl]-3,4-dihydroxyfuran-2(5H)-one', 'Methyl (L)-α-aspartyl-(L)-phenylalaninate', '(3-methylbutyl) nitrite', '[(6-O-β-(D)-Glucopyranosyl-β-(D)-glucopyranosyl)oxy](phenyl)acetonitrile', '(2S,3S,4S,5R,6R)-6-[(R)-cyano(phenyl)methoxy]-3,4,5-trihydroxyoxane-2-carboxylic acid', 'Boron nitride']
# <http://dbpedia.org/ontology/largestWin>
# ['Hibernian 22–1 Black Watch Highlanders', '(Edinburgh, Scotland; 3 September 1881)', 'Dundee United1–12 Motherwell (1954)', '6–2 vsD.C. United', 'September 19, 2000', 'RFK Stadium', '4–0 vsT.B. Mutiny', 'May 26, 2001', 'Raymond James Sta.', '6–2 vsDallas Burn']
# <http://dbpedia.org/ontology/leaderTitle>
# ['President', 'Prime Minister', 'Co-Princes', 'Representative', 'Prime Minister', 'Monarch', 'Governor', 'Prime Minister', 'President', 'Vice President']
# <http://dbpedia.org/ontology/legislativePeriodName>
# ['18th Bundestag', '8th European Parliament', '56th UK Parliament', '56th UK Parliament', '56th UK Parliament', '8th term', 'Legislative body in theSoviet Union', '114th United States Congress', 'Mayor of London elected every four years', 'London Assembly elected every four years']
# <http://dbpedia.org/ontology/liberationDate>
# ['Soviet Union, January 27, 1945', 'Closed in late 1943', 'Canadian 2nd Infantry Division', 'Yugoslav Partisans', 'Closed before end of war', 'United Kingdom and Canada, April 15, 1945', 'French 1st Army,U.S. 6th Army Group, 23 November 1944', 'Soviet Union, July 22, 1944', 'British Army', 'United States, 29 April 1945']
# <http://dbpedia.org/ontology/licensee>
# ['AnimEigo', 'American Broadcasting Companies, Inc.', 'Televicentro of Puerto Rico, LLC', 'Geneon Entertainment', 'Radio License Holdings LLC', 'Corus Premium Television Ltd.', 'Entercom Buffalo License, LLC', '(Expired)', 'Ion Media License Company, LLC', 'WPIX, LLC']
# <http://dbpedia.org/ontology/locationIdentifier>
# ['EG74', 'CES3', 'MAA', 'CQM', 'TAL', 'CKM9', '(Location of airport in Mexico)', 'CPG', 'SDR', 'FIN']
# <http://dbpedia.org/ontology/logo>
# ['Rolling Stone logo.svg', 'Scientific American logo.svg', 'Time_Magazine_logo.svg', 'Los Angeles Xtreme.png', 'Las Vegas Outlaws.png', 'The Atlantic magazine logo.svg', '200px', 'Ct logo.svg', 'File:Newsweek Logo.svg', 'center|frame|S&T issue 68 cover']
# <http://dbpedia.org/ontology/longName>
# ["People's Democratic Republic of Algeria", 'Principality of Andorra', 'Aruba', 'Republic of Angola', 'Islamic Republic of Afghanistan', 'font-size:88%;', 'Republic of Albania', 'Republic of Azerbaijan', 'Antigua and Barbuda', 'Anguilla']
# <http://dbpedia.org/ontology/longtype>
# ['of Final Fantasy: The Spirits Within', 'ofcover songs', '/soundtrack', '/soundtrack', 'to the film Jay and Silent Bob Strike Back', 'series', '/Soundtrack', '(Digital download/ Audio CD)', 'withstudio tracks', 'companion album to Super Fly']
# <http://dbpedia.org/ontology/lowest>
# ['Sea level', 'Doghole Bridge', 'Sea level', 'Sea level', 'Sea level', 'Berounka River', 'sea level(at the Hudson River and onLong Island Sound)', 'Roaring Fork at N corner of city', 'Sea level(at the Hudson River)', 'Sea level']
# <http://dbpedia.org/ontology/managerTitle>
# ['Head coach', 'Head coach', 'Head coach', 'Head coach', 'Manager', 'Manager', 'Head coach', 'Manager', 'Head coach', 'Manager']
# <http://dbpedia.org/ontology/mapCaption>
# ['Location of Auschwitz in contemporary Poland', 'Location of the camp in the Netherlands', 'Location of Bergen-Belsen inLower Saxony', 'Natzwiller,France', 'Location of Neuengamme in Germany', 'Location of Dachau inUpper Bavaria', 'Location of Ohrdruf in Germany', 'Location of Villa Baviera in Chile', 'Location of the camp in Belgium', 'Location of Višegrad inBosnia and Herzegovina']
# <http://dbpedia.org/ontology/mascot>
# ['Sparky', 'Bruno theBear', 'Millie the Dancing Bear', 'Brody the Bruin', 'Beaver', 'Columbia Lions', 'Mario the Magnificent', 'The Patriot', '(formerly \\', 'Turbo the Tornado']
# <http://dbpedia.org/ontology/material>
# ['Coral,limestone', 'Coral,limestone', 'Wood', 'Wood', 'Wood', 'Wood', 'Wood', 'Wood', 'Copper', 'Granite']
# <http://dbpedia.org/ontology/meaning>
# ['FromAdria', '\\', 'resurrection', 'A holiday celebrating trees.', '\\', 'Commemorates the beginning of theFrench Revolutionwith theStorming of the Bastilleon 14 July 1789, and the unity of the French people at theFête de la Fédérationon 14 July 1790', 'beginning of summer', 'Commemoration of the birth ofJesus', '\\', "TheMaccabeessuccessfullyrebelledagainstAntiochus IV Epiphanes. According to theTalmud, a late text, the Temple was purified and thewicks of the menorah miraculously burned for eight days, even though there was only enough sacred oil for one day's lighting."]
# <http://dbpedia.org/ontology/membership>
# ['125,000 companies and 3.5 million professionals', '500,000 members', '67 countries', '100,000', '47 member states', '5 Council observers', '3 Assembly observers', '181,543  (as of 10 August 2016)', '48 countries', '6,058 (including 4,470 priests)']
# <http://dbpedia.org/ontology/meshName>
# ['Adrenal+Glands', 'Bone', 'Cervix+uteri', 'Clitoris', '197', 'Endometrium', 'Entorhinal+Cortex', 'Foot', 'Glottis', 'Hair']
# <http://dbpedia.org/ontology/militaryCommand>
# ['1st Texas Rifles (USV)', '2nd U.S. Cavalry', 'Department of the Pacific(USA)', 'Army of Central Kentucky(CSA)', 'Army of Mississippi(CSA)', 'Department No. 2 (CSA)', 'I Corps', '35th U.S. Infantry', '24th U.S. Infantry', 'ProminentMujahideencommander during theSoviet war in Afghanistan']
# <http://dbpedia.org/ontology/militaryUnitSize>
# ['28,568 (Regular)', '14,662 (Active Reserve)', '12,806', '87,610 Regular', '30,000Regular Reserve', '28,800Volunteer Reserve', '16 officers, 110 enlisted', '1,350 in 2012', 'c. 7,700 men in eleven regiments and one sub-unit', '16,200 personnel (29 February 2016)']
# <http://dbpedia.org/ontology/month>
# ['October', 'December', 'April', 'July', 'July', 'June', 'September', 'May', 'April', 'January']
# <http://dbpedia.org/ontology/motto>
# ['By the people and for the people', 'Virtus Unita Fortior', '\\', 'Ti Shqipëri, më jep nder, më jep emrin Shqipëtar', 'Heldhaftig, Vastberaden, Barmhartig(Valiant, Steadfast, Compassionate)', '\\', '\\', '\\', 'For the Queen, the Law and the People', "Because Freedom Can't Protect Itself"]
# <http://dbpedia.org/ontology/muteCharacterInPlay>
# ['Godot', 'Two guards', 'A boy', 'Man', 'Daughters ofOedipus(AntigoneandIsmene)', '* Ismenia', '* Corinthian Woman', '* Reconciliation', '* Four Scythian Policemen', '* Scythian Policewoman']
# <http://dbpedia.org/ontology/name>
# ['Khunjerab Pass', 'Brenner Pass', 'Col du Mont Ventoux', 'Col du Tourmalet', 'Col du Galibier', 'Great St Bernard Pass', 'Yonkers Raceway at Empire City Casino', 'Torugart Pass', 'Delaware Water Gap', 'Greenwood']
# <http://dbpedia.org/ontology/nationalTopographicSystemMapNumber>
# ['OSLandranger 41, Explorer 392', 'NTS115B', 'USGSMount Baker', 'USGSMount St. Helens', 'Geospatial Information Authority25000:1', '50000:1', 'USGSHalf Dome', 'OSLandranger 73', 'USGSMount Shasta', 'OSLandranger 174']
# <http://dbpedia.org/ontology/neighbourConstellations>
# ['Pisces', 'Pegasus', 'Equuleus', 'Delphinus', 'Aquila', 'Capricornus', 'Piscis Austrinus', 'Sculptor', 'Cetus', '*']
# <http://dbpedia.org/ontology/note>
# ['Equipped with streamlined roof and rear window.', '8 units written-off after damages fromHurricane Katrina.', 'FormerlyNOPSI410–517.', 'FormerlyNOPSI518-702.', 'FormerlyNOPSI703–761.', 'Used on Vieux Carre Trolley.', '25 units written-off after damages fromHurricane Katrina.', '18 units written-off after damages fromHurricane Katrina.', '73 units written-off after damages fromHurricane Katrina.', '52 units written-off after damages fromHurricane Katrina.']
# <http://dbpedia.org/ontology/notes>
# ['aOver 10,000 Axis soldiers continued to fight until early March 1943.', '1 Italyprovided fourmotor torpedo boatstoLake Ladoga.', '2 TheUnited Kingdomdeclared war on Finland but conducted no operations after that.', 'Often served with a side ofketchup,mayonnaise,vinegar,barbecue sauce, or othersauce', 'Southern Food', '&sup1; The exact number of Iraqi Shia that fought alongside Iran is unknown. TheIslamic Supreme Council of IraqandIslamic Dawa Partysupported Iran during the war. Iran would sometimes organise divisions of Iraqi POWs to fight against Iraq.', 'http://www.jello.com', 'a. Until 15 March 1917.', 'Acannedprecooked meat product', 'Civilians killed: 1,841 (or 1,935 inc. ex-combatants)']
# <http://dbpedia.org/ontology/offeredClasses>
# ['Mathematics,Computer Science,Humanities, andScience', 'Regular, Career Focus,Advanced Placement', 'Arabic,Chinese,Danish,English,Finnish,French,German,Italian,Japanese,Korean,Norwegian,Portuguese,Russian,Spanish,Swedish', '616', 'General education', 'International Baccalaureate', 'UKGtoStandard XII', 'All Advanced Placement classes plus elective and core classes', 'Form 1 - Upper 6', 'Art, Business, Campus Ministry, English, Mathematics, Music, PE/Health, Science, Social Studies, Technology, Theology, World Languages']
# <http://dbpedia.org/ontology/office>
# ['16th President of the United States', 'Member of theIllinois House of Representatives', '16th President of the United States', 'Member of theIllinois House of Representatives', 'Minister of Armaments and War Production', 'Minister of Armaments and War Production', 'Prime Minister of Canada', 'Prime Minister of Canada', '17th President of the United States', '16th Vice President of the United States']
# <http://dbpedia.org/ontology/officialSchoolColour>
# ['ASU Maroon and Gold', 'blueandgold', 'Garnetandblue', 'Brown, Red, White', 'Blue and white', 'Blue and white', 'Orange and white', 'Columbia blueand white', 'Blue and Gold', 'Dartmouth Green']
# <http://dbpedia.org/ontology/openAccessContent>
# ['Yes', 'Delayed, after 5 years', 'Yes', 'No', 'No', 'No', 'Hybridanddelayed', 'Delayed', 'Hybrid', 'No']
# <http://dbpedia.org/ontology/orderInOffice>
# ['2nd', '38thGovernor of California', 'Chairman of the DAP', 'Shadow Home Secretary', '1st', '1stGovernor of New South Wales', '11th', 'Prime Minister of Israel', '40th and 42ndGovernor of Arkansas', '42nd President of the United States']
# <http://dbpedia.org/ontology/originallyUsedFor>
# ['Army barracks', 'Extermination camp', 'Extermination camp', 'Prisoner of war camp, later civilian internment camp', 'Extermination camp', 'Forced labor', 'Political prison', 'High school', 'Prisoner of war camp', 'Subterranean fuel depot (tunnels)']
# <http://dbpedia.org/ontology/otherChannel>
# ['WNJX-TV4.1Mayagüez', 'WTIN-TV 4.1Ponce', '(WPXU-LD 12.1Amityville, New York)', 'Hachiōji, Tokyo', 'Analog: Channel 31', 'Tama, Tokyo', 'Analog: Channel 55', 'Chichi-jima, Ogasawara Islands', 'Analog: Channel 57', 'Haha-jima, Ogasawara Islands']
# <http://dbpedia.org/ontology/otherName>
# ['Beinn Nibheis', 'جبل رم', 'Λύκαιος ορος', 'Mons Lycaeus', 'Kulshan', 'Louwala-Clough', 'Ibn Sina Peak', 'הַר הַבַּיִת, Har HaBayit', 'الحرم الشريف, al-Ḥaram ash-Šarīf,', 'הַר הַזֵּיתִים, Har HaZeitim']
# <http://dbpedia.org/ontology/otherServingLines>
# ['Metro Transit routes5, 54, 415, 515, 540, and 542', 'MVTAroutes 444 and 495', ':MTA New York City Subway:', ':at34th Street – Penn Station(Seventh Avenue)', ':at34th Street – Penn Station(Eighth Avenue)', ':MTA New York City Bus:M4,M7,M20,M34/M34ASBS,Q32', ':Academy Bus: X23, X24', ':Amtrak Thruway Motorcoach: service to airports via New York Airport Service', ':Eastern Shuttle', ':Greyhound Lines:BoltBusand NeOn']
# <http://dbpedia.org/ontology/oversight>
# ['New York City Department of Education', 'Montgomery County Public Schools', 'NYC Department of Education', 'Western Assn of Schools and Colleges,Accrediting Commission for Schools', 'North Carolina Department of Public Instruction, Exceptional Children Division', 'Diocese of Joliet', 'Janesville School District', 'Bedford Central School District', 'Hunter College', 'Columbia Public Schools']
# <http://dbpedia.org/ontology/parkingInformation>
# ['Available, Paid', 'None', '2,448', 'No', 'None, but available in various parts of Downtown Plano within walking distance', '778 free spaces, no overnight', '2,078 free spaces, no overnight (DART site says - 2,078 spaces,, overnight or long-term parking is at the discretion of the customer. DART assumes no responsibility for vehicles left overnight)', '568 free spaces, no overnight', 'none', '271 free spaces, no overnight']
# <http://dbpedia.org/ontology/participant>
# ['8 (1960–1965), 9 (1966–1967), 10 (1968–1970)', 'Kansas City Chiefs', 'Kansas City Chiefs/Dallas Texans (3)', 'Leicester City(1st title)', 'Max 12', 'Milano Rhinos', 'Juventus(32nd title)', '[[#Clubs', 'Denver Broncos', '(3rd title)']
# <http://dbpedia.org/ontology/passengersUsedSystem>
# ['Amtrak', 'Amtrak', 'Amtrak', 'Amtrak', 'MARC', 'Metro', 'Metro', 'Metro', 'WMATA', 'Metro']
# <http://dbpedia.org/ontology/personName>
# ['Susan N. Herman', 'Anthony Romero', 'Takehiko Nakao', 'Carlos Alvarez', 'Vicki L. Hanson', 'M.J.T. Milton', 'Gabriella Battaini-Dragoni', 'Anne Brasseur', 'Edmond Panariti', 'Jean-Claude Frécon']
# <http://dbpedia.org/ontology/plays>
# ['Right-handed (two-handed backhand)', 'Right-handed (two-handed backhand)', 'Right-handed (two-handed backhand)', 'Right-handed (two-handed backhand)', 'Right-handed (two-handed backhand)', 'Right-handed (one-handed backhand)', 'Right-handed (two-handed backhand)', 'Right-handed (one-handed backhand)', 'Right-handed (one-handed backhand)', 'Right-handed (one handed-backhand)']
# <http://dbpedia.org/ontology/portfolio>
# ['Chairman for federal investigations of Communists in the U.S. government', 'Parliamentary Secretary to the Minister of International Cooperation', 'Parliamentary Secretary to the Minister of Citizenship and Immigration (2000-2003)', 'Minister of Transport, Infrastructure and Communities', 'Minister of Human Resources and Social Development', 'Parliamentary Assistant to the Minister of Labour (1943–1945)', 'Leader of the Government in the Senate (1969–1974)', 'Families', 'Canada:', 'Speaker of the Senate (1891–1896)']
# <http://dbpedia.org/ontology/projectKeyword>
# ['Drug discovery,Drug development', 'North Korea,Geography,Politics,Government', 'Europass,EQF,ECVET,competences, agriculture', 'EQF,Sewage Treatment,Water Sector,competences', 'security,computer data processing,metadata,digital watermarking,artificial intelligence,signal processing', 'Agriculture,Aquaculture,Open Access,Research', 'Government,e-Learning,Research', 'Drug discovery,drug development', 'Heritage interpretation,Europeanisationofmuseums', 'Statistics,Probability distribution']
# <http://dbpedia.org/ontology/pseudonym>
# ['Ayn Rand', 'Mary Westmacott', 'Agatha Christie', 'Acton Bell', 'A. E. Housman', 'Vincent Omniaveritas (infanzineCheap Truth)', 'Jael Cracken, Dr. Peristyle, C. C. Shackleton', 'Polisseno Fegeio, Pastor Arcade', 'N. W. Clerk', 'Lord Charles Albert']
# <http://dbpedia.org/ontology/publiclyAccessible>
# ['Open year round', 'Open year round', 'Open year round except Christmas Day', 'Open year round', 'Public', 'Mojave National Preserve, National Parks (Death Valley,Joshua Tree,Zion, andGrand Canyon)', 'Federal lands: restrictions,', 'Private lands: some grant permission', 'Public', 'Public']
# <http://dbpedia.org/ontology/purpose>
# ['National standards', 'Civil liberties advocacy', 'To end child malnutrition while providing communities with access to safe water and sustainable solutions to hunger.', 'Social and economic development', '*Liberation of Austro-Hungarian South Slavs (Yugoslavism)', '*Unification of ethnic Serb territories (Pan-Serbism)', 'Conservation and Preservation', 'Hacking', 'Spacecraft ground control', 'Environmentalism,peace']
# <http://dbpedia.org/ontology/quote>
# ['Safety at SeaandRoyal Belgian Institute of Natural Sciences', 'Institute of Marine Research, Norway', 'GNISfeature ID 272820', 'GNIS ID: 856349', 'Specifications, Elan Valley Visitor Centre.', 'State of the Lakes Report', 'SSSI Ref 1002739', 'NVE', 'NVE', 'World Lakes Database']
# <http://dbpedia.org/ontology/railwayPlatforms>
# ['24 (22 in use)', '12 (Numbered 0–11)', '13', '3 (numbered 2 – 4)', '8', '2', '18', '4', 'Island platform', '1side platform']
# <http://dbpedia.org/ontology/reportingMark>
# ['LI', 'TGV,Intercités,TER,Transilien,Ouigo,Eurostar,Thalys,TGV Lyria', 'LMS', 'KTM', 'PE', 'CN', 'BNSF', 'MNCW', 'SP', 'MILW']
# <http://dbpedia.org/ontology/reservations>
# ['false', 'false', 'true', 'false', 'true', 'true', 'true', 'true', 'false', 'false']
# <http://dbpedia.org/ontology/result>
# ['American victory', '*Peace of Paris', '*Britishrecognition of the independence of theUnited States of America', '* End of theFirst British Empire', '* Shattering of theIroquois Confederacy', 'Unionvictory', '*Slaveryabolished', '*Territorial integritypreserved', '* Destruction and dissolution of theConfederate States', '* Beginning of theReconstruction Era']
# <http://dbpedia.org/ontology/review>
# ['http://www.allmusic.com/cg/amg.dll?p=amg&sql=10:1e841vgjzzua', 'http://www.allmusic.com/cg/amg.dll?p=amg&sql=10:6zri287c05oa', 'http://allmusic.com/cg/amg.dll?p=amg&token=&sql=10:pt2m967oaep1', 'http://articles.latimes.com/2006/jun/18/entertainment/ca-rack18', 'http://www.stylusmagazine.com/reviews/field-mob/light-poles-and-pine-trees.htm', 'http://books.google.com/books?id=_iYEAAAAMBAJ&pg=PA144&dq=revolutions&lr=&as_pt=MAGAZINES&hl=fr&rview=1&cd=83#v=onepage&q=revolutions&f=false', 'http://pitchfork.com/reviews/albums/9174-blessphemy-of-the-peace-beast-feastgiver-and-the-bear-warp-kumite/', 'http://www.allmusic.com/cg/amg.dll?p=amg&sql=10:aifexql5ldse', 'http://www.stylusmagazine.com/feature.php?ID=2022', 'http://www.allmusic.com/cg/amg.dll?p=amg&sql=10:fvftxzwaldte']
# <http://dbpedia.org/ontology/role>
# ['Ground defence of Bosnia and Herzegovina', 'Land warfare', 'Aerobaticflight demonstration team', 'Militia', 'Foreign Infantry, Foreignairborne infantry, Foreign armoured cavalry, Foreign combat engineer, Foreignairborne engineer, Regimental Foreignmilitary police', 'Protection of Christian Pilgrims', 'Light infantry', 'Naval warfare', 'Aerial warfare', 'Naval warfare']
# <http://dbpedia.org/ontology/routeEndDirection>
# ['North', 'North', 'East', 'East', 'West', 'North', 'East', 'East', 'East', 'East']
# <http://dbpedia.org/ontology/routeStartDirection>
# ['South', 'South', 'West', 'West', 'East', 'South', 'West', 'West', 'West', 'West']
# <http://dbpedia.org/ontology/runwaySurface>
# ['Asphalt', 'Closed', 'Groovedasphalt', 'Concrete', 'Asphalt', 'Asphalt/Concrete', 'Concrete', 'Planned', 'Grass', 'Concrete']
# <http://dbpedia.org/ontology/seniority>
# ['United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'United States Senator', 'Senator']
# <http://dbpedia.org/ontology/servingTemperature>
# ['Chilled or room temperature', 'Often room temperature, although they may be served when still warm from the oven', 'Hot, generally salted', 'Cold', 'Hot or warm', 'Room temperature', 'Hot', 'cold, hot', 'Hot or cold', 'Hot or cold']
# <http://dbpedia.org/ontology/settingOfPlay>
# ['The home of the Helmer family in an unspecified Norwegian town or city, circa 1879.', "Shakespeare's Hamlet", 'Chicago, 1930s', 'London and an estate inHertfordshire', '1783&ndash;1825; Vienna, Austria; the Court of Joseph II', 'TheFrench QuarterandDowntown New Orleans', "Upstairs and downstairs of the Marryot's house", "Martha and George's New England home", 'ADerbyshirecountry estatein both the past (1809, 1812) and \\', "The Birlings' home in Brumley, England; April 1912"]
# <http://dbpedia.org/ontology/sex>
# ['Stallion', 'Stallion', 'Stallion', 'Stallion', 'Stallion', 'Gelding', 'Stallion', 'Stallion', 'Stallion', 'Gelding']
# <http://dbpedia.org/ontology/shareSource>
# ['BARB', 'BARB', 'BARB', 'BARB', 'RAJAR–Quarterly Listening', 'BARB', 'BARB', 'http://www.rajar.co.uk/listening/quarterly_listening.php', 'BARB', 'BARB']
# <http://dbpedia.org/ontology/shoots>
# ['Left', 'Left', 'Left', 'Right', 'Left', 'right', 'Left', 'Left', 'Ambidextrous', 'Right']
# <http://dbpedia.org/ontology/signature>
# ['Abraham Lincoln 1862 signature.svg', 'Albert Speer Signature.svg', 'Alexander Mackenzie Signature-rt.svg', 'Andrew Johnson Signature.svg', 'Andrew Jackson Signature-.svg', 'Arnold Schwarzenegger Signature.svg', 'Arthur st clair signature.svg', 'Aung San Suu Kyi signature 2013.svg', 'Benjamin Franklin Signature.svg', 'BarryGoldwaterSig.png']
# <http://dbpedia.org/ontology/slogan>
# ['Where It Begins', '\\', '\\', 'Live The Story', "The World's Newsroom", '\\', 'Fair & Balanced', 'Simplify your Digital Life', 'Here on NBC', 'We Love Music']
# <http://dbpedia.org/ontology/specialist>
# ['Science', 'Languages', 'Sports', 'Language', 'Science College', 'Science(Primary)', 'Languages(Secondary)', 'Maths & Computing', 'Music', 'Sports College']
# <http://dbpedia.org/ontology/stationStructure>
# ['demolished', 'demolished', 'At-grade', 'Standard on-ground station', 'Elevated', 'Ground', 'Ground level withmezzanine', 'Elevated', 'At grade', 'Elevated']
# <http://dbpedia.org/ontology/status>
# ['Historic,Unsupported', 'Current', '501(c)(3)', 'Active', 'Treaty', 'Active', 'Discontinued', 'Active', 'Active', 'Retired since 1971']
# <http://dbpedia.org/ontology/strength>
# ['United States:', '40,000 (Average)', '5,000Continental Navysailors (at height in 1779)', 'no ships of the line', '53 other ships (active at some point during the war)', 'Allies:', '36,000 French (in America)', '63,000 French and Spanish (at Gibraltar)', '146 ships of the line (active 1782)', 'Native Allies: Unknown']
# <http://dbpedia.org/ontology/subjectOfPlay>
# ['The awakening of a middle-class wife and mother.', "Adolf Hitler's rise to power", 'Biography of Wolfgang Amadeus Mozart', 'Death,War,Titanic,Great Depression,Romance,20th century', 'Reckoning,Salvation', 'Marital strife', 'Love and war', 'History, science, philosophy, mathematics, love, death', 'A mysterious inspector interrogates a wealthy English family about their responsibility for the death of a young working class factory girl.', 'Life and death in an American small town']
# <http://dbpedia.org/ontology/subtitle>
# ['The Fast-Dealing Property Trading Game', 'The American Tribal Love-Rock Musical', 'featuring the songs of ABBA', 'A Musical Fable', '(previously titled Bounce)', 'Drinking Game', '\\', 'A Storytelling Game of Epic Horror', 'Drinking Game', 'or Sunny Ceylon']
# <http://dbpedia.org/ontology/symbol>
# ['β-lactamase domain', 'CTRB1', 'CTRB2', 'CTRC', 'Collagen', 'LIG1', 'LIG3', 'LIG4', '7tm_1', 'Histone']
# <http://dbpedia.org/ontology/synonym>
# ['* Boa (Linnaeus, 1758)', '* Euhaliotis (Wenz, 1938)', '* Eurotis (Habe & Kosuge, 1964)', '* Exohaliotis (Cotton& Godfrey, 1933)', '* Haliotis (Haliotis) (Linnaeus, 1758)', '* Haliotis (Nordotis) (Habe & Kosuge, 1964)', '* Haliotis (Notohaliotis) (Cotton& Godfrey, 1933)', '* Haliotis (Padollus) (Montfort, 1810)', '* Haliotis (Paua) (C. Fleming, 1953)', '* Haliotis (Sulculus) (H. Adams&A. Adams, 1854)']
# <http://dbpedia.org/ontology/teamName>
# ['Alumni', 'British and Irish Lions', 'The Lions', 'Bruins', 'Five Nations', 'Crimsons/Rams', 'Raider', 'Trojans', 'Big Blue', 'UTS Blues']
# <http://dbpedia.org/ontology/tennisSurfaceType>
# ['Hardcourt', 'Grass', 'Rebound Ace', 'DecoTurf', 'Neodex', 'Hard', 'Hardcourt (Rebound Ace)', 'Hardcourt (Rebound Ace)', 'Clay', 'Clay (Red)']
# <http://dbpedia.org/ontology/throwingSide>
# ['Left', 'Right', 'Right', 'Right', 'Left', 'Right', 'Right', 'Right', 'Right', 'Right']
# <http://dbpedia.org/ontology/timeshiftChannel>
# ['Channel 4 +1', 'Channel 4 +1 HD', 'Disney Channel East', 'Disney Channel West', 'Showtime East,', 'Showtime West,', 'Showtime 2 East,', 'Showtime 2 West,', 'Showcase East,', 'Showcase West,']
# <http://dbpedia.org/ontology/title>
# ['Film director', 'Film producer', 'Screenwriter', '\\', '\\', "That's one small step ...", 'Film director', 'BasileusofMacedon,Hegemonof theHellenic League,ShahanshahofPersia,PharaohofEgypt,Lord of Asia', 'Ruler of the Hunnic Empire', 'Film director,film producer']
# <http://dbpedia.org/ontology/transmission>
# ['4-speedmanual', '5-speedmanual', '4-speedautomatic', '5-speedmanual', '4-speedautomatic', '6-speed manual', '5-speedmanual', '6-speedautomatic', '6-speed manual', '6-speedSkyActiv-MTManual']
# <http://dbpedia.org/ontology/uciCode>
# ['DSC', 'THR', 'AST', 'C.A', 'TNK', 'EUS', 'MOV', 'COA (2000-2003)', 'TBI (2003)', 'COF']
# <http://dbpedia.org/ontology/valvetrain>
# ['SOHC', 'I-head', 'SOHC', 'SOHC', 'SOHC', 'SOHC', 'SOHC', 'SOHC', 'SOHC', 'SOHC']
# <http://dbpedia.org/ontology/victims>
# ['MainlyJews,Poles,Romani, Soviet soldiers', 'Anne Frank,Otto Frank,Viktor Frankl,Imre Kertész,Maximilian Kolbe,Primo Levi,Witold Pilecki,Edith Stein,Simone Veil,Rudolf Vrba,Elie Wiesel,Fritz Löhner-Beda,Else Ury', 'Jews, mostly Polish', '*', 'Richard Glazar', 'Artur Gold', 'Janusz Korczak', 'Jankiel Wiernik', 'Samuel Willenberg', 'Anne Frank,Dora Gerson,Etty Hillesum,Philip Slier,Edith Stein,Selma Wijnberg-Engel,Max Ehrlich,Wilhelm Mautner,Ellen Burka']
# <http://dbpedia.org/ontology/whaDraft>
# ['6th overall', '6th overall', '28th overall', '7th overall', '36th overall', '44th overall', '18th overall', '10th overall', '29th overall', '37th overall']
# <http://dbpedia.org/ontology/worstDefeat>
# ['Rangers10–0 Hibernian', '(Glasgow, Scotland; 24 December 1898)', 'Aberdeen8–0 Motherwell (1979)', '6–1 vsSan Jose Clash', 'September 19, 1999', 'Spartan Stadium', '0–7,Antalyaspor, 13 May 2016', '0–6 vsA.D. Isidro Metapán', '(Estadio Jorge Calero Suárez; October 27, 2007)', '0–6 vsOnce Municipal']
# <http://purl.org/dc/elements/1.1/description>
# ['Protein structure', 'X-ray crystallography', 'NMR Structure Determination', 'A large and extensively accessed biological database about fish', 'Nucleotide sequences for more than 300,000 organisms with supporting bibliographic and biological annotation.', 'Catalog of all known human genes and genetic phenotypes.', 'Protein Structure Classification', 'Protein Structure Classification', 'Medical Subject Headings', 'UniProt is the Universal Protein resource, a central repository ofproteindata created by combining the Swiss-Prot, TrEMBL and PIR-PSDdatabases.']
# <http://purl.org/dc/elements/1.1/publisher>
# ['Harcourt Brace Jovanovich', 'Tor Books', 'Propyläen Verlag', 'South End Press', 'Bantam', 'Directorate of Intelligence', 'Jonathan Cape', 'Putnam', 'Putnam', '1759: Cramer, Marc-Michel Rey, Jean Nourse, Lambert, and others']
# <http://purl.org/dc/elements/1.1/type>
# ['music', 'music', 'speech', 'music', 'music', 'speech', 'speech', 'speech', 'speech', 'music']
# <http://xmlns.com/foaf/0.1/familyName>
# ['Helppi', 'Antonius', 'Lam', 'Haber', 'Angelo', 'Akenhead', 'Cada', 'Sahamies', 'Kelopuro', 'Kiivramees']
# <http://xmlns.com/foaf/0.1/givenName>
# ['Kim Renard Nazel', 'Angela Maria DiFranco', 'Alexis Andrew Nicholas Koerner', 'Amy Lee Grant', 'Alexandar Zivojinovich', 'Amr Abdel-Basset Abdel-Azeez Diab عمرو عبدالباسط عبدالعزيز دياب', 'Arlo Davy Guthrie', 'Barb Wire', 'Arthur Blake', 'Charles Hardin Holley']
# <http://xmlns.com/foaf/0.1/name>
# ['Autism', 'State of Alabama', 'Abraham Lincoln', 'Animalia', 'Academy Awards', 'Actresses', 'Allan Dwan', 'Alain Connes', 'Aristotle', 'Academy Award for Best Production Design']
# <http://xmlns.com/foaf/0.1/nick>
# ['Heart of Turkey', 'Mokum, Damsko', "Feast of All Souls; Defuncts' Day; Commemoration of the Faithful Departed", 'Dodo', '\\', 'Algiers the White; Algiers the Dazzling', 'The Austrian Oak', 'Sun Devils', "The Nation's Capital", '\\']

# %%
df_subset['len'] = df_subset['to'].str.len()
# Out:
# c:\Users\Jeremy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_subset.groupby('relation').describe()
# Out:
#                                                           len             \
#                                                         count       mean
# relation
# <http://dbpedia.org/ontology/aSide>                    2979.0   4.959047
# <http://dbpedia.org/ontology/abbreviation>            10464.0  10.838589
# <http://dbpedia.org/ontology/access>                    387.0  42.700258
# <http://dbpedia.org/ontology/address>                 56143.0  24.000356
# <http://dbpedia.org/ontology/agencyStationCode>       10385.0   4.811266
# <http://dbpedia.org/ontology/alias>                   55278.0  15.296085
# <http://dbpedia.org/ontology/allegiance>              21032.0  15.802159
# <http://dbpedia.org/ontology/alternativeName>            31.0  20.387097
# <http://dbpedia.org/ontology/atcSupplemental>           104.0  14.278846
# <http://dbpedia.org/ontology/background>              83193.0  14.693700
# <http://dbpedia.org/ontology/battingSide>               664.0   4.698795
# <http://dbpedia.org/ontology/battleHonours>            2959.0  27.518080
# <http://dbpedia.org/ontology/bestFinish>                343.0  33.827988
# <http://dbpedia.org/ontology/bicycleInformation>       2637.0   7.870686
# <http://dbpedia.org/ontology/birthName>               79134.0  19.632939
# <http://dbpedia.org/ontology/brainInfoType>             372.0   4.215054
# <http://dbpedia.org/ontology/bridgeCarries>            3275.0  22.682137
# <http://dbpedia.org/ontology/callSign>                 3742.0   7.914751
# <http://dbpedia.org/ontology/callsignMeaning>         13201.0  20.259374
# <http://dbpedia.org/ontology/campusType>               1877.0   8.200852
# <http://dbpedia.org/ontology/canBaggageChecked>        1356.0   4.684366
# <http://dbpedia.org/ontology/causalties>              17906.0  17.078856
# <http://dbpedia.org/ontology/certification>            3853.0  12.121983
# <http://dbpedia.org/ontology/chairmanTitle>            5383.0   8.795281
# <http://dbpedia.org/ontology/characterInPlay>          5600.0  12.911429
# <http://dbpedia.org/ontology/chorusCharacterInP...       61.0  18.573770
# <http://dbpedia.org/ontology/cityType>                  530.0   5.330189
# <http://dbpedia.org/ontology/coachingRecord>            110.0  38.854545
# <http://dbpedia.org/ontology/code>                     1564.0   5.838875
# <http://dbpedia.org/ontology/coden>                    2115.0   6.020331
# ...                                                       ...        ...
# <http://dbpedia.org/ontology/shareSource>              1139.0  17.521510
# <http://dbpedia.org/ontology/shoots>                  14315.0   4.320433
# <http://dbpedia.org/ontology/signature>                1912.0  29.296025
# <http://dbpedia.org/ontology/slogan>                  18098.0  19.926511
# <http://dbpedia.org/ontology/specialist>                721.0  21.105409
# <http://dbpedia.org/ontology/stationStructure>         7926.0  12.408529
# <http://dbpedia.org/ontology/status>                  47976.0  22.896177
# <http://dbpedia.org/ontology/strength>                34863.0  17.018272
# <http://dbpedia.org/ontology/subjectOfPlay>             614.0  39.666124
# <http://dbpedia.org/ontology/subtitle>                  248.0  23.625000
# <http://dbpedia.org/ontology/symbol>                   4271.0   7.736596
# <http://dbpedia.org/ontology/synonym>                253511.0  33.417386
# <http://dbpedia.org/ontology/teamName>                 7463.0  11.821519
# <http://dbpedia.org/ontology/tennisSurfaceType>         933.0   6.978564
# <http://dbpedia.org/ontology/throwingSide>              658.0   4.790274
# <http://dbpedia.org/ontology/timeshiftChannel>          276.0  15.931159
# <http://dbpedia.org/ontology/title>                  247497.0  19.984113
# <http://dbpedia.org/ontology/transmission>            10932.0  19.004574
# <http://dbpedia.org/ontology/uciCode>                   387.0   4.118863
# <http://dbpedia.org/ontology/valvetrain>                491.0   4.456212
# <http://dbpedia.org/ontology/victims>                    95.0  33.000000
# <http://dbpedia.org/ontology/whaDraft>                  359.0  12.033426
# <http://dbpedia.org/ontology/worstDefeat>                62.0  27.612903
# <http://purl.org/dc/elements/1.1/description>           373.0  50.847185
# <http://purl.org/dc/elements/1.1/publisher>           31906.0  16.981947
# <http://purl.org/dc/elements/1.1/type>                 2636.0   7.523900
# <http://xmlns.com/foaf/0.1/familyName>                   20.0   5.800000
# <http://xmlns.com/foaf/0.1/givenName>                 32453.0  17.069054
# <http://xmlns.com/foaf/0.1/name>                    3368646.0  15.741737
# <http://xmlns.com/foaf/0.1/nick>                      52506.0  12.790462
#
#                                                                            \
#                                                           std  min    25%
# relation
# <http://dbpedia.org/ontology/aSide>                  8.120586  1.0   1.00
# <http://dbpedia.org/ontology/abbreviation>           8.403624  1.0   4.00
# <http://dbpedia.org/ontology/access>                45.522392  1.0  17.00
# <http://dbpedia.org/ontology/address>               12.608319  1.0  16.00
# <http://dbpedia.org/ontology/agencyStationCode>      4.614200  1.0   3.00
# <http://dbpedia.org/ontology/alias>                 13.266190  1.0   9.00
# <http://dbpedia.org/ontology/allegiance>             8.786674  1.0   9.00
# <http://dbpedia.org/ontology/alternativeName>       10.922995  4.0  12.00
# <http://dbpedia.org/ontology/atcSupplemental>       10.410466  1.0   5.00
# <http://dbpedia.org/ontology/background>             5.356666  2.0  11.00
# <http://dbpedia.org/ontology/battingSide>            0.567813  3.0   4.00
# <http://dbpedia.org/ontology/battleHonours>         47.000823  1.0  11.00
# <http://dbpedia.org/ontology/bestFinish>            14.455503  1.0  25.00
# <http://dbpedia.org/ontology/bicycleInformation>     9.523051  1.0   3.00
# <http://dbpedia.org/ontology/birthName>              6.557558  1.0  15.00
# <http://dbpedia.org/ontology/brainInfoType>          0.411413  4.0   4.00
# <http://dbpedia.org/ontology/bridgeCarries>         16.293450  1.0  11.00
# <http://dbpedia.org/ontology/callSign>               5.866824  1.0   5.00
# <http://dbpedia.org/ontology/callsignMeaning>       17.706273  1.0   8.00
# <http://dbpedia.org/ontology/campusType>             5.893479  1.0   5.00
# <http://dbpedia.org/ontology/canBaggageChecked>      0.464939  4.0   4.00
# <http://dbpedia.org/ontology/causalties>            21.214660  1.0   8.00
# <http://dbpedia.org/ontology/certification>          6.388566  1.0  10.00
# <http://dbpedia.org/ontology/chairmanTitle>          2.456398  3.0   8.00
# <http://dbpedia.org/ontology/characterInPlay>       11.911459  1.0   6.00
# <http://dbpedia.org/ontology/chorusCharacterInP...  27.206285  4.0  11.00
# <http://dbpedia.org/ontology/cityType>               1.972982  4.0   4.00
# <http://dbpedia.org/ontology/coachingRecord>        20.164387  1.0  28.00
# <http://dbpedia.org/ontology/code>                   8.571606  1.0   2.00
# <http://dbpedia.org/ontology/coden>                  1.044453  2.0   6.00
# ...                                                       ...  ...    ...
# <http://dbpedia.org/ontology/shareSource>           23.558069  1.0   3.00
# <http://dbpedia.org/ontology/shoots>                 0.497526  1.0   4.00
# <http://dbpedia.org/ontology/signature>              7.951069  5.0  25.00
# <http://dbpedia.org/ontology/slogan>                16.215488  1.0   9.00
# <http://dbpedia.org/ontology/specialist>            15.371962  2.0  12.00
# <http://dbpedia.org/ontology/stationStructure>       7.933741  4.0   8.00
# <http://dbpedia.org/ontology/status>                21.495256  1.0   7.00
# <http://dbpedia.org/ontology/strength>              17.236520  1.0   7.00
# <http://dbpedia.org/ontology/subjectOfPlay>         30.482219  1.0  16.25
# <http://dbpedia.org/ontology/subtitle>              11.289730  1.0  15.75
# <http://dbpedia.org/ontology/symbol>                 5.954721  1.0   4.00
# <http://dbpedia.org/ontology/synonym>               12.939798  1.0  26.00
# <http://dbpedia.org/ontology/teamName>               8.031250  1.0   7.00
# <http://dbpedia.org/ontology/tennisSurfaceType>      4.448027  4.0   4.00
# <http://dbpedia.org/ontology/throwingSide>           0.463357  3.0   5.00
# <http://dbpedia.org/ontology/timeshiftChannel>      10.344202  4.0  10.00
# <http://dbpedia.org/ontology/title>                 16.767569  1.0   8.00
# <http://dbpedia.org/ontology/transmission>          16.049871  1.0  13.00
# <http://dbpedia.org/ontology/uciCode>                3.265669  3.0   3.00
# <http://dbpedia.org/ontology/valvetrain>             0.840078  4.0   4.00
# <http://dbpedia.org/ontology/victims>               35.993498  1.0  12.50
# <http://dbpedia.org/ontology/whaDraft>               1.069641  9.0  12.00
# <http://dbpedia.org/ontology/worstDefeat>           12.802862  2.0  20.00
# <http://purl.org/dc/elements/1.1/description>       35.742068  7.0  31.00
# <http://purl.org/dc/elements/1.1/publisher>          9.854694  1.0  12.00
# <http://purl.org/dc/elements/1.1/type>               5.321379  1.0   5.00
# <http://xmlns.com/foaf/0.1/familyName>               1.962812  3.0   4.00
# <http://xmlns.com/foaf/0.1/givenName>                6.319838  1.0  13.00
# <http://xmlns.com/foaf/0.1/name>                     8.833617  1.0  11.00
# <http://xmlns.com/foaf/0.1/nick>                    12.643652  1.0   5.00
#
#
#                                                      50%    75%     max
# relation
# <http://dbpedia.org/ontology/aSide>                  1.0   5.00    99.0
# <http://dbpedia.org/ontology/abbreviation>           8.0  16.00    78.0
# <http://dbpedia.org/ontology/access>                27.0  52.00   449.0
# <http://dbpedia.org/ontology/address>               21.0  29.00   257.0
# <http://dbpedia.org/ontology/agencyStationCode>      3.0   4.00    45.0
# <http://dbpedia.org/ontology/alias>                 13.0  18.00   336.0
# <http://dbpedia.org/ontology/allegiance>            14.0  24.00   119.0
# <http://dbpedia.org/ontology/alternativeName>       17.0  25.00    46.0
# <http://dbpedia.org/ontology/atcSupplemental>       14.0  18.25    41.0
# <http://dbpedia.org/ontology/background>            13.0  13.00   179.0
# <http://dbpedia.org/ontology/battingSide>            5.0   5.00     7.0
# <http://dbpedia.org/ontology/battleHonours>         16.0  24.00   560.0
# <http://dbpedia.org/ontology/bestFinish>            32.0  41.00    81.0
# <http://dbpedia.org/ontology/bicycleInformation>     3.0  10.00   126.0
# <http://dbpedia.org/ontology/birthName>             19.0  23.00   132.0
# <http://dbpedia.org/ontology/brainInfoType>          4.0   4.00     5.0
# <http://dbpedia.org/ontology/bridgeCarries>         18.0  29.00   210.0
# <http://dbpedia.org/ontology/callSign>               7.0   7.00    72.0
# <http://dbpedia.org/ontology/callsignMeaning>       17.0  26.00   360.0
# <http://dbpedia.org/ontology/campusType>             7.0   8.00    88.0
# <http://dbpedia.org/ontology/canBaggageChecked>      5.0   5.00     5.0
# <http://dbpedia.org/ontology/causalties>            12.0  21.00  1396.0
# <http://dbpedia.org/ontology/certification>         11.0  15.00    70.0
# <http://dbpedia.org/ontology/chairmanTitle>          9.0   9.00    31.0
# <http://dbpedia.org/ontology/characterInPlay>       11.0  15.00   230.0
# <http://dbpedia.org/ontology/chorusCharacterInP...  14.0  18.00   218.0
# <http://dbpedia.org/ontology/cityType>               4.0   7.00    10.0
# <http://dbpedia.org/ontology/coachingRecord>        39.0  47.00   111.0
# <http://dbpedia.org/ontology/code>                   2.0   6.00   107.0
# <http://dbpedia.org/ontology/coden>                  6.0   6.00    40.0
# ...                                                  ...    ...     ...
# <http://dbpedia.org/ontology/shareSource>            5.0  20.00   176.0
# <http://dbpedia.org/ontology/shoots>                 4.0   5.00    12.0
# <http://dbpedia.org/ontology/signature>             28.0  32.00    77.0
# <http://dbpedia.org/ontology/slogan>                20.0  28.00   387.0
# <http://dbpedia.org/ontology/specialist>            18.0  27.00   124.0
# <http://dbpedia.org/ontology/stationStructure>      11.0  11.00   101.0
# <http://dbpedia.org/ontology/status>                17.0  31.00   916.0
# <http://dbpedia.org/ontology/strength>              13.0  20.00   618.0
# <http://dbpedia.org/ontology/subjectOfPlay>         31.0  55.00   178.0
# <http://dbpedia.org/ontology/subtitle>              22.0  30.00    68.0
# <http://dbpedia.org/ontology/symbol>                 6.0  10.00   107.0
# <http://dbpedia.org/ontology/synonym>               34.0  40.00   394.0
# <http://dbpedia.org/ontology/teamName>               9.0  15.00   187.0
# <http://dbpedia.org/ontology/tennisSurfaceType>      4.0  12.00    33.0
# <http://dbpedia.org/ontology/throwingSide>           5.0   5.00     7.0
# <http://dbpedia.org/ontology/timeshiftChannel>      14.0  19.00   105.0
# <http://dbpedia.org/ontology/title>                 15.0  27.00   667.0
# <http://dbpedia.org/ontology/transmission>          16.0  22.00   348.0
# <http://dbpedia.org/ontology/uciCode>                3.0   3.00    21.0
# <http://dbpedia.org/ontology/valvetrain>             4.0   4.00     6.0
# <http://dbpedia.org/ontology/victims>               19.0  38.50   166.0
# <http://dbpedia.org/ontology/whaDraft>              12.0  12.00    24.0
# <http://dbpedia.org/ontology/worstDefeat>           25.0  34.00    59.0
# <http://purl.org/dc/elements/1.1/description>       43.0  62.00   331.0
# <http://purl.org/dc/elements/1.1/publisher>         15.0  20.00   282.0
# <http://purl.org/dc/elements/1.1/type>               5.0   7.00    79.0
# <http://xmlns.com/foaf/0.1/familyName>               6.0   7.25    10.0
# <http://xmlns.com/foaf/0.1/givenName>               17.0  21.00   131.0
# <http://xmlns.com/foaf/0.1/name>                    14.0  19.00   836.0
# <http://xmlns.com/foaf/0.1/nick>                     9.0  17.00   491.0
#
# [165 rows x 8 columns]

# %%
df_subset['len'].quantile(.8)
# Out:
# 24.0

# %%
q = df_subset.groupby('relation')['len'].quantile(.8)

# %%
q[:60]
# Out:
# relation
# <http://dbpedia.org/ontology/aSide>                     10.0
# <http://dbpedia.org/ontology/abbreviation>              18.0
# <http://dbpedia.org/ontology/access>                    61.8
# <http://dbpedia.org/ontology/address>                   32.0
# <http://dbpedia.org/ontology/agencyStationCode>          4.0
# <http://dbpedia.org/ontology/alias>                     20.0
# <http://dbpedia.org/ontology/allegiance>                24.0
# <http://dbpedia.org/ontology/alternativeName>           30.0
# <http://dbpedia.org/ontology/atcSupplemental>           23.0
# <http://dbpedia.org/ontology/background>                24.0
# <http://dbpedia.org/ontology/battingSide>                5.0
# <http://dbpedia.org/ontology/battleHonours>             26.0
# <http://dbpedia.org/ontology/bestFinish>                44.6
# <http://dbpedia.org/ontology/bicycleInformation>        13.0
# <http://dbpedia.org/ontology/birthName>                 24.0
# <http://dbpedia.org/ontology/brainInfoType>              5.0
# <http://dbpedia.org/ontology/bridgeCarries>             32.0
# <http://dbpedia.org/ontology/callSign>                   7.0
# <http://dbpedia.org/ontology/callsignMeaning>           29.0
# <http://dbpedia.org/ontology/campusType>                 9.0
# <http://dbpedia.org/ontology/canBaggageChecked>          5.0
# <http://dbpedia.org/ontology/causalties>                23.0
# <http://dbpedia.org/ontology/certification>             15.0
# <http://dbpedia.org/ontology/chairmanTitle>              9.0
# <http://dbpedia.org/ontology/characterInPlay>           17.0
# <http://dbpedia.org/ontology/chorusCharacterInPlay>     18.0
# <http://dbpedia.org/ontology/cityType>                   7.0
# <http://dbpedia.org/ontology/coachingRecord>            49.2
# <http://dbpedia.org/ontology/code>                       8.0
# <http://dbpedia.org/ontology/coden>                      6.0
# <http://dbpedia.org/ontology/collection>                35.0
# <http://dbpedia.org/ontology/colourName>                12.0
# <http://dbpedia.org/ontology/combatant>                 23.0
# <http://dbpedia.org/ontology/committee>                 68.0
# <http://dbpedia.org/ontology/configuration>             13.0
# <http://dbpedia.org/ontology/crownDependency>           11.0
# <http://dbpedia.org/ontology/cuisine>                   21.8
# <http://dbpedia.org/ontology/currentStatus>              6.0
# <http://dbpedia.org/ontology/currentlyUsedFor>          22.0
# <http://dbpedia.org/ontology/demonym>                   15.0
# <http://dbpedia.org/ontology/depictionDescription>      52.0
# <http://dbpedia.org/ontology/description>               68.0
# <http://dbpedia.org/ontology/detectionMethod>           18.6
# <http://dbpedia.org/ontology/digitalSubChannel>         16.0
# <http://dbpedia.org/ontology/draft>                     13.0
# <http://dbpedia.org/ontology/dressCode>                 11.0
# <http://dbpedia.org/ontology/editorTitle>               15.0
# <http://dbpedia.org/ontology/eyeColor>                   5.0
# <http://dbpedia.org/ontology/faaLocationIdentifier>      3.0
# <http://dbpedia.org/ontology/fansgroup>                 19.0
# <http://dbpedia.org/ontology/fareZone>                  11.0
# <http://dbpedia.org/ontology/fate>                      35.0
# <http://dbpedia.org/ontology/filename>                  45.0
# <http://dbpedia.org/ontology/firstAppearance>           24.0
# <http://dbpedia.org/ontology/firstGame>                 40.0
# <http://dbpedia.org/ontology/flag>                      30.0
# <http://dbpedia.org/ontology/formerName>                33.0
# <http://dbpedia.org/ontology/frequencyOfPublication>     9.0
# <http://dbpedia.org/ontology/frozen>                    16.0
# <http://dbpedia.org/ontology/fuelType>                   6.0
# Name: len, dtype: float64
